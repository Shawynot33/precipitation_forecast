# %% [markdown]
# # **Experiment Notebook**

# %%
# Do not modify this code
# !pip install -q utstd

from utstd.ipyrenders import *

# %%
# Do not modify this code
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ## 0. Import Packages

# %%
# 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import mutual_info_regression, mutual_info_classif

import matplotlib.dates as mdates

from statsmodels.tsa.seasonal import seasonal_decompose

from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import TimeSeriesSplit

from sklearn.metrics import mean_squared_error, mean_absolute_error
import xgboost as xgb

from hyperopt import fmin, tpe, hp, Trials, STATUS_OK

# %%
# Import custom package
# !pip install my_krml_25552249==2025.0.7.0
# Out:
# Collecting my_krml_25552249==2025.0.7.0
#   Using cached my_krml_25552249-2025.0.7.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pandas==2.2.2 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from my_krml_25552249==2025.0.7.0) (2.2.2)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.5.1 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from my_krml_25552249==2025.0.7.0) (1.5.1)
# Requirement already satisfied: numpy>=1.23.2 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from pandas==2.2.2->my_krml_25552249==2025.0.7.0) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from pandas==2.2.2->my_krml_25552249==2025.0.7.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from pandas==2.2.2->my_krml_25552249==2025.0.7.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from pandas==2.2.2->my_krml_25552249==2025.0.7.0) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.5.1->my_krml_25552249==2025.0.7.0) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.5.1->my_krml_25552249==2025.0.7.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.5.1->my_krml_25552249==2025.0.7.0) (3.6.0)
# Requirement already satisfied: six>=1.5 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2->my_krml_25552249==2025.0.7.0) (1.17.0)
# Using cached my_krml_25552249-2025.0.7.0-py3-none-any.whl (11 kB)
# Installing collected packages: my_krml_25552249
#   Attempting uninstall: my_krml_25552249
#     Found existing installation: my_krml_25552249 2025.0.7.1
#     Uninstalling my_krml_25552249-2025.0.7.1:
#       Successfully uninstalled my_krml_25552249-2025.0.7.1
# Successfully installed my_krml_25552249-2025.0.7.0

# %% [markdown]
# ---
# ## A. Project Description

# %%
# <Student to fill this section>
student_name = "Shawya Saito"
student_id = "25552249"

# %%
# Do not modify this code
print_tile(size="h1", key='student_name', value=student_name)
# Out:
# <p style="color:grey">student_name</p><h1 font-size: 3em>Shawya Saito</h1>

# %%
# Do not modify this code
print_tile(size="h1", key='student_id', value=student_id)
# Out:
# <p style="color:grey">student_id</p><h1 font-size: 3em>25552249</h1>

# %% [markdown]
# ---
# ## B. Business Understanding

# %%
# <Student to fill this section>
business_use_case_description = """
Explain clearly what is the goal of this project for the business.
"""

# %%
# Do not modify this code
print_tile(size="h3", key='business_use_case_description', value=business_use_case_description)
# Out:
# <p style="color:grey">business_use_case_description</p><h3 font-size: 3em>
# Explain clearly what is the goal of this project for the business.
# </h3>

# %%
# <Student to fill this section>
business_objectives = """
What will be the impact of accurate or incorrect results?
"""

# %%
# Do not modify this code
print_tile(size="h3", key='business_objectives', value=business_objectives)
# Out:
# <p style="color:grey">business_objectives</p><h3 font-size: 3em>
# What will be the impact of accurate or incorrect results?
# </h3>

# %%
# <Student to fill this section>
stakeholders_expectations_explanations = """
How will the results be used?
Who will be the users of your predictions? Who will be impacted by your predictions?
"""

# %%
# Do not modify this code
print_tile(size="h3", key='stakeholders_expectations_explanations', value=stakeholders_expectations_explanations)
# Out:
# <p style="color:grey">stakeholders_expectations_explanations</p><h3 font-size: 3em>
# How will the results be used?
# Who will be the users of your predictions? Who will be impacted by your predictions?
# </h3>

# %% [markdown]
# ---
# ## C. Data Understanding

# %% [markdown]
# ### C.1   Load Datasets

# %%
# Load training data
X_data = pd.read_csv('../../data/processed/X_data_reg.csv')
y_data = pd.read_csv('../../data/processed/y_data_reg.csv')

# Load test data
X_test = pd.read_csv('../../data/processed/X_test_reg.csv')
y_test = pd.read_csv('../../data/processed/y_test_reg.csv')

# %% [markdown]
# Dropping dow_cos, dow_sin. Keeping the other rest

# %% [markdown]
# ## D.z Final Selection of Features

# %%
# <Student to fill this section>

features_list = [
    'precipitation_sum',
    'precip_sum_lag1', 
    'precip_sum_lag2', 
    'precipitation_hours',
    'cloud_cover_mean',
    'wind_direction_10m_dominant',
    'vapour_pressure_deficit_max',
    'shortwave_radiation_sum',
    'wind_gusts_10m_min'
]
target = ['precipitation_sum_next_3_days']

# %%
# <Student to fill this section>
feature_selection_explanations = """
provide a quick explanation on the features selected
"""

# %%
# Do not modify this code
print_tile(size="h3", key='feature_selection_explanations', value=feature_selection_explanations)
# Out:
# <p style="color:grey">feature_selection_explanations</p><h3 font-size: 3em>
# provide a quick explanation on the features selected
# </h3>

# %% [markdown]
# ---
# ## E. Data Preparation

# %% [markdown]
# ### E.1 Data Transformation <put_name_here>

# %%
# <Student to fill this section>

# %%
# <Student to fill this section>
data_cleaning_1_explanations = """
Provide some explanations on why you believe it is important to fix this issue and its impacts
"""

# %%
# Do not modify this code
print_tile(size="h3", key='data_cleaning_1_explanations', value=data_cleaning_1_explanations)
# Out:
# <p style="color:grey">data_cleaning_1_explanations</p><h3 font-size: 3em>
# Provide some explanations on why you believe it is important to fix this issue and its impacts
# </h3>

# %% [markdown]
# ---
# ## F. Feature Engineering

# %% [markdown]
# ### F.2 New Feature "precipitation sum lag1 and lag2"

# %%
# <Student to fill this section>

# %%
# <Student to fill this section>
feature_engineering_2_explanations = """
Provide some explanations on why you believe it is important to create this feature and its impacts
"""

# %%
# Do not modify this code
print_tile(size="h3", key='feature_engineering_2_explanations', value=feature_engineering_2_explanations)
# Out:
# <p style="color:grey">feature_engineering_2_explanations</p><h3 font-size: 3em>
# Provide some explanations on why you believe it is important to create this feature and its impacts
# </h3>

# %% [markdown]
# ---
# ## G. Data Preparation for Modeling

# %% [markdown]
# ### G.1 Split Datasets

# %%
X_data = X_data[features_list]
X_test = X_test[features_list]

# %% [markdown]
# ---
# ## H. Save Datasets
#
# > Do not change this code

# %%
# # Do not modify this code
# # Save training set
# try:
#   X_train.to_csv(at.folder_path / 'X_train.csv', index=False)
#   y_train.to_csv(at.folder_path / 'y_train.csv', index=False)

#   X_val.to_csv(at.folder_path / 'X_val.csv', index=False)
#   y_val.to_csv(at.folder_path / 'y_val.csv', index=False)

#   X_test.to_csv(at.folder_path / 'X_test.csv', index=False)
#   y_test.to_csv(at.folder_path / 'y_test.csv', index=False)
# except Exception as e:
#   print(e)

# %%
# # Do not modify this code
# # Save training set
# try:
#   X_data.to_csv('../../data/processed/X_data_reg.csv', index=False)
#   y_data.to_csv('../../data/processed/y_data_reg.csv', index=False)

#   X_test.to_csv('../../data/processed/X_test_reg.csv', index=False)
#   y_test.to_csv('../../data/processed/y_test_reg.csv', index=False)
# except Exception as e:
#   print(e)

# %% [markdown]
# ---
# ## I. Selection of Performance Metrics
#
# > Provide some explanations on why you believe the performance metrics you chose is appropriate

# %%
# RMSE main scoring metric, also look at mae and r^2

# %%
# <Student to fill this section>
performance_metrics_explanations = """
Provide some explanations on why you believe the performance metrics you chose is appropriate
"""

# %%
# Do not modify this code
print_tile(size="h3", key='performance_metrics_explanations', value=performance_metrics_explanations)
# Out:
# <p style="color:grey">performance_metrics_explanations</p><h3 font-size: 3em>
# Provide some explanations on why you believe the performance metrics you chose is appropriate
# </h3>

# %% [markdown]
# ## J. Train Machine Learning Model

# %% [markdown]
# ### J.1 Import Algorithm
#
# > Provide some explanations on why you believe this algorithm is a good fit

# %%
# <Student to fill this section>
algorithm_selection_explanations = """
Provide some explanations on why you believe this algorithm is a good fit
"""

# %%
# Do not modify this code
print_tile(size="h3", key='algorithm_selection_explanations', value=algorithm_selection_explanations)
# Out:
# <p style="color:grey">algorithm_selection_explanations</p><h3 font-size: 3em>
# Provide some explanations on why you believe this algorithm is a good fit
# </h3>

# %% [markdown]
# ### J.2 Set Hyperparameters
#
# > Provide some explanations on why you believe this algorithm is a good fit

# %%
# <Student to fill this section>

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %%
space = {
    'max_depth': hp.choice('max_depth', range(2, 10)),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.01), np.log(0.3)),
    'n_estimators': hp.choice('n_estimators', range(50, 500)),
    'subsample': hp.uniform('subsample', 0.6, 1.0),
    'colsample_bytree': hp.uniform('colsample_bytree', 0.6, 1.0)
}

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Objective function
def objective(params):
    rmses = []
    maes = []
    pct_errors = []

    for train_idx, val_idx in tscv.split(X_data):
        X_train, X_val = X_data.iloc[train_idx], X_data.iloc[val_idx]
        y_train, y_val = y_data.iloc[train_idx], y_data.iloc[val_idx]

        model = xgb.XGBRegressor(
            **params,
            random_state=33,
            objective='reg:squarederror',
            tree_method='hist',
            early_stopping_rounds=20,
            n_jobs=-1
        )

        model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=False)

        preds = model.predict(X_val)
        rmses.append(mean_squared_error(y_val, preds, squared=False))
        maes.append(mean_absolute_error(y_val, preds))

    return {
        'loss': np.mean(rmses),
        'status': STATUS_OK,
        'fold_rmse': rmses,
        'fold_mae': maes,
    }

# Run Hyperopt
trials = Trials()
best = fmin(
    fn=objective,
    space=space,
    algo=tpe.suggest,
    max_evals=50,
    trials=trials
)
# Out:
# 100%|██████████████████████████████████████| 50/50 [00:29<00:00,  1.69trial/s, best loss: 14.204759777649524]

# %%
# Best trial index
best_trial_idx = np.argmin([t['result']['loss'] for t in trials.trials])
best_trial = trials.trials[best_trial_idx]

# Fold-wise metrics for best hyperparameters
print("Fold-wise RMSE:", best_trial['result']['fold_rmse'])
print("Mean RMSE:", best_trial['result']['loss'])
print("Fold-wise MAE:", best_trial['result']['fold_mae'])
print("Mean MAE:", np.mean(best_trial['result']['fold_mae']))
print("\n")
# Best hyperparameters
print("Best hyperparameters:", best)
# Out:
# Fold-wise RMSE: [np.float64(10.946472931811474), np.float64(15.091750061953329), np.float64(11.348105639924027), np.float64(17.957044947014325), np.float64(15.680425307544464)]
# Mean RMSE: 14.204759777649524
# Fold-wise MAE: [np.float64(6.000817850782175), np.float64(7.014829048402202), np.float64(6.614461533032581), np.float64(8.18256740726787), np.float64(8.560200801827506)]
# Mean MAE: 7.2745753282624666
#
#
# Best hyperparameters: {'colsample_bytree': np.float64(0.7623669058561658), 'learning_rate': np.float64(0.044327838472859586), 'max_depth': np.int64(1), 'n_estimators': np.int64(377), 'subsample': np.float64(0.7237521990896351)}

# %%
# <Student to fill this section>
hyperparameters_selection_explanations = """
Explain why you are tuning these hyperparameters
"""

# %%
# Do not modify this code
print_tile(size="h3", key='hyperparameters_selection_explanations', value=hyperparameters_selection_explanations)
# Out:
# <p style="color:grey">hyperparameters_selection_explanations</p><h3 font-size: 3em>
# Explain why you are tuning these hyperparameters
# </h3>

# %% [markdown]
# ### J.3 Fit Model

# %%
# <Student to fill this section>

# %%
# Map 'max_depth' choice index back to actual value
max_depth_choices = list(range(1, 10))

final_params = {
    'max_depth': max_depth_choices[int(best['max_depth'])],   # convert index to actual depth
    'n_estimators': int(best['n_estimators']),
    'learning_rate': float(best['learning_rate']),
    'subsample': float(best['subsample']),
    'colsample_bytree': float(best['colsample_bytree']),
    'random_state': 33,                                       
    'objective': 'reg:squarederror',
    'tree_method': 'hist',
    'n_jobs': -1
}

# %%
# Instantiate final model
final_model = xgb.XGBRegressor(**final_params)

# Fit on all training data
final_model.fit(X_data, y_data)

# Predict on test set
y_pred = final_model.predict(X_test)

# %%
# Save final model
import joblib
from joblib import dump

try:
    dump(final_model, '../../models/precipitation_fall/xgb_model_reg.joblib')
except Exception as e:
    print(e)

# %% [markdown]
# ### J.4 Model Technical Performance
#
# > Provide some explanations on model performance

# %%
# <Student to fill this section>

# %%
# RMSE
test_rmse = mean_squared_error(y_test, y_pred, squared=False)

# MAE
test_mae = mean_absolute_error(y_test, y_pred)

print("Test RMSE:", test_rmse)
print("Test MAE:", test_mae)
# Out:
# Test RMSE: 13.938793989370343
# Test MAE: 8.133055936896737

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("Test R-squared:", r2)
# Out:
# Test R-squared: 0.10524576902389526

# %%
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Predicted vs Actual Precipitation")
plt.show()

# %%
y_test_series = y_test.squeeze()  # converts single-column DataFrame to Series

# %%
# Calculate residuals
residuals = y_test_series - y_pred

# Scatter plot of residuals vs predicted values
plt.figure(figsize=(8,5))
plt.scatter(y_pred, residuals, alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Precipitation")
plt.ylabel("Residuals")
plt.title("Residuals vs Predicted")
plt.show()

# Histogram of residuals
plt.figure(figsize=(8,5))
plt.hist(residuals, bins=50, edgecolor='k', alpha=0.7)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Residuals Distribution")
plt.show()

# %%
# Plot importances
ax = xgb.plot_importance(final_model)
ax.grid(False)
plt.show()

# %%
# Compute mean of training target
train_mean = y_data.mean()

# Predict test set with this mean
y_pred_baseline = np.full_like(y_test, fill_value=train_mean, dtype=np.float64)

# Evaluate
baseline_rmse = mean_squared_error(y_test, y_pred_baseline, squared=False)
baseline_mae = mean_absolute_error(y_test, y_pred_baseline)

print("Baseline RMSE on test set:", baseline_rmse)
print("Baseline MAE on test set:", baseline_mae)
# Out:
# Baseline RMSE on test set: 14.829742435731161
# Baseline MAE on test set: 8.966953614260683

# %%
# <Student to fill this section>
model_performance_explanations = """
Provide some explanations on model performance
"""

# %%
# Do not modify this code
print_tile(size="h3", key='model_performance_explanations', value=model_performance_explanations)
# Out:
# <p style="color:grey">model_performance_explanations</p><h3 font-size: 3em>
# Provide some explanations on model performance
# </h3>

# %% [markdown]
# ### J.5 Business Impact from Current Model Performance
#
# > Provide some analysis on the model impacts from the business point of view

# %%
# <Student to fill this section>

# %%
# <Student to fill this section>
business_impacts_explanations = """
Interpret the results of the experiments related to the business objective set earlier. Estimate the impacts of the incorrect results for the business (some results may have more impact compared to others)
"""

# %%
# Do not modify this code
print_tile(size="h3", key='business_impacts_explanations', value=business_impacts_explanations)
# Out:
# <p style="color:grey">business_impacts_explanations</p><h3 font-size: 3em>
# Interpret the results of the experiments related to the business objective set earlier. Estimate the impacts of the incorrect results for the business (some results may have more impact compared to others)
# </h3>

# %% [markdown]
# ## H. Project Outcomes

# %%
# <Student to fill this section>
experiment_outcome = "" # Either 'Hypothesis Confirmed', 'Hypothesis Partially Confirmed' or 'Hypothesis Rejected'

# %%
# Do not modify this code
print_tile(size="h2", key='experiment_outcomes_explanations', value=experiment_outcome)
# Out:
# <p style="color:grey">experiment_outcomes_explanations</p><h2 font-size: 3em></h2>

# %%
# <Student to fill this section>
experiment_results_explanations = """
Reflect on the outcome of the experiment and list the new insights you gained from it. Provide rationale for pursuing more experimentation with the current approach or call out if you think it is a dead end.
Given the results achieved and the overall objective of the project, list the potential next steps and experiments. For each of them assess the expected uplift or gains and rank them accordingly. If the experiment achieved the required outcome for the business, recommend the steps to deploy this solution into production.
"""

# %%
# Do not modify this code
print_tile(size="h2", key='experiment_results_explanations', value=experiment_results_explanations)
# Out:
# <p style="color:grey">experiment_results_explanations</p><h2 font-size: 3em>
# Reflect on the outcome of the experiment and list the new insights you gained from it. Provide rationale for pursuing more experimentation with the current approach or call out if you think it is a dead end.
# Given the results achieved and the overall objective of the project, list the potential next steps and experiments. For each of them assess the expected uplift or gains and rank them accordingly. If the experiment achieved the required outcome for the business, recommend the steps to deploy this solution into production.
# </h2>
