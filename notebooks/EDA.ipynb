# %% [markdown]
# # Exploratory Data Analysis

# %%
# Do not modify this code
# !pip install -q utstd

from utstd.ipyrenders import *
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Do not modify this code
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ## Import packages

# %%
# !pip install my_krml_25552249==2025.0.6.2
# Out:
# Requirement already satisfied: my_krml_25552249==2025.0.6.2 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (2025.0.6.2)
# Requirement already satisfied: pandas==2.2.2 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from my_krml_25552249==2025.0.6.2) (2.2.2)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.5.1 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from my_krml_25552249==2025.0.6.2) (1.5.1)
# Requirement already satisfied: numpy>=1.23.2 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from pandas==2.2.2->my_krml_25552249==2025.0.6.2) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from pandas==2.2.2->my_krml_25552249==2025.0.6.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from pandas==2.2.2->my_krml_25552249==2025.0.6.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from pandas==2.2.2->my_krml_25552249==2025.0.6.2) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.5.1->my_krml_25552249==2025.0.6.2) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.5.1->my_krml_25552249==2025.0.6.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.5.1->my_krml_25552249==2025.0.6.2) (3.6.0)
# Requirement already satisfied: six>=1.5 in /Users/shawya1/Library/Caches/pypoetry/virtualenvs/adv-mla-at2-ySRGTB_r-py3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2->my_krml_25552249==2025.0.6.2) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the data

# %%
df = pd.read_csv("../data/raw/sydney_weather_2010_2024.csv")

# %%
df.head(15)
# Out:
#           time  weather_code  temperature_2m_max  temperature_2m_min  \
# 0   2010-01-01            53                25.7                21.1
# 1   2010-01-02            63                26.9                21.0
# 2   2010-01-03            51                20.6                19.5
# 3   2010-01-04            51                22.5                19.2
# 4   2010-01-05             3                26.0                18.6
# 5   2010-01-06             3                24.7                20.5
# 6   2010-01-07             3                23.1                19.6
# 7   2010-01-08            51                24.5                20.8
# 8   2010-01-09             3                30.4                20.1
# 9   2010-01-10             1                27.3                21.3
# 10  2010-01-11             3                24.8                20.8
# 11  2010-01-12            51                30.4                21.2
# 12  2010-01-13            53                25.8                20.3
# 13  2010-01-14             3                22.7                19.9
# 14  2010-01-15            51                23.4                21.1
#
#     apparent_temperature_max  apparent_temperature_min  precipitation_sum  \
# 0                       26.7                      24.2                3.9
# 1                       32.6                      22.2                8.6
# 2                       21.3                      19.2                1.1
# 3                       22.3                      19.5                0.6
# 4                       30.0                      19.8                0.0
# 5                       28.9                      21.1                0.0
# 6                       23.1                      20.0                0.0
# 7                       26.1                      22.2                0.5
# 8                       35.8                      22.6                0.0
# 9                       30.9                      23.1                0.0
# 10                      26.3                      22.2                0.0
# 11                      35.9                      23.7                0.3
# 12                      28.9                      19.7                0.9
# 13                      23.1                      19.5                0.0
# 14                      24.9                      22.7                1.7
#
#     rain_sum  snowfall_sum  precipitation_hours  ...            sunset  \
# 0        3.9           0.0                 12.0  ...  2010-01-01T19:09
# 1        8.6           0.0                 14.0  ...  2010-01-02T19:09
# 2        1.1           0.0                  7.0  ...  2010-01-03T19:09
# 3        0.6           0.0                  4.0  ...  2010-01-04T19:09
# 4        0.0           0.0                  0.0  ...  2010-01-05T19:09
# 5        0.0           0.0                  0.0  ...  2010-01-06T19:09
# 6        0.0           0.0                  0.0  ...  2010-01-07T19:09
# 7        0.5           0.0                  4.0  ...  2010-01-08T19:09
# 8        0.0           0.0                  0.0  ...  2010-01-09T19:09
# 9        0.0           0.0                  0.0  ...  2010-01-10T19:09
# 10       0.0           0.0                  0.0  ...  2010-01-11T19:09
# 11       0.3           0.0                  1.0  ...  2010-01-12T19:09
# 12       0.9           0.0                  2.0  ...  2010-01-13T19:09
# 13       0.0           0.0                  0.0  ...  2010-01-14T19:09
# 14       1.7           0.0                  5.0  ...  2010-01-15T19:09
#
#    sunshine_duration  daylight_duration  wind_speed_10m_max  \
# 0           11820.64           51690.04                18.6
# 1           47009.17           51656.75                15.6
# 2               0.00           51620.64                18.3
# 3           33312.08           51581.75                16.9
# 4           48326.60           51540.10                17.5
# 5           48285.53           51495.73                18.7
# 6           32123.54           51448.26                14.9
# 7           30252.90           51397.43                14.4
# 8           48145.75           51343.39                13.7
# 9           48093.24           51286.26                18.7
# 10          46738.82           51226.14                21.5
# 11          47979.96           51163.18                18.9
# 12          45992.49           51097.48                25.7
# 13           8371.99           51029.18                19.2
# 14           9170.60           50958.38                14.4
#
#     wind_gusts_10m_max  wind_direction_10m_dominant  shortwave_radiation_sum  \
# 0                 35.6                          332                    10.13
# 1                 37.4                          299                    23.62
# 2                 37.4                          147                     6.71
# 3                 37.4                           70                    15.84
# 4                 39.2                           35                    30.14
# 5                 40.0                          148                    27.29
# 6                 32.8                          147                    15.25
# 7                 32.0                           71                    18.83
# 8                 28.8                           17                    29.25
# 9                 41.4                          160                    30.68
# 10                45.7                           70                    23.79
# 11                38.5                           37                    29.77
# 12                54.7                          157                    27.87
# 13                38.5                          166                    10.39
# 14                32.0                          139                     9.22
#
#     et0_fao_evapotranspiration  rain_in_7_days  precipitation_next_3_days
# 0                         2.46               1                       10.3
# 1                         4.57               0                        1.7
# 2                         2.14               0                        0.6
# 3                         3.50               0                        0.0
# 4                         5.62               1                        0.5
# 5                         4.94               1                        0.5
# 6                         3.49               0                        0.5
# 7                         3.87               1                        0.0
# 8                         6.17               0                        0.3
# 9                         5.89               1                        1.2
# 10                        4.56               0                        1.2
# 11                        6.04               0                        2.6
# 12                        5.26               0                        1.7
# 13                        2.78               0                       10.5
# 14                        2.21               0                        8.8
#
# [15 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4745 entries, 0 to 4744
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   time                         4745 non-null   object
#  1   weather_code                 4745 non-null   int64
#  2   temperature_2m_max           4745 non-null   float64
#  3   temperature_2m_min           4745 non-null   float64
#  4   apparent_temperature_max     4745 non-null   float64
#  5   apparent_temperature_min     4745 non-null   float64
#  6   precipitation_sum            4745 non-null   float64
#  7   rain_sum                     4745 non-null   float64
#  8   snowfall_sum                 4745 non-null   float64
#  9   precipitation_hours          4745 non-null   float64
#  10  sunrise                      4745 non-null   object
#  11  sunset                       4745 non-null   object
#  12  sunshine_duration            4745 non-null   float64
#  13  daylight_duration            4745 non-null   float64
#  14  wind_speed_10m_max           4745 non-null   float64
#  15  wind_gusts_10m_max           4745 non-null   float64
#  16  wind_direction_10m_dominant  4745 non-null   int64
#  17  shortwave_radiation_sum      4745 non-null   float64
#  18  et0_fao_evapotranspiration   4745 non-null   float64
#  19  rain_in_7_days               4745 non-null   int64
#  20  precipitation_next_3_days    4745 non-null   float64
# dtypes: float64(15), int64(3), object(3)
# memory usage: 778.6+ KB

# %%
df.describe()
# Out:
#        weather_code  temperature_2m_max  temperature_2m_min  \
# count   4745.000000         4745.000000         4745.000000
# mean      29.188198           21.375511           14.005669
# std       26.357187            4.537295            4.469756
# min        0.000000            9.800000            0.900000
# 25%        3.000000           17.700000           10.400000
# 50%       51.000000           21.200000           14.000000
# 75%       53.000000           24.400000           17.900000
# max       65.000000           41.800000           26.900000
#
#        apparent_temperature_max  apparent_temperature_min  precipitation_sum  \
# count               4745.000000               4745.000000        4745.000000
# mean                  21.232160                 13.113109           2.388788
# std                    6.420427                  6.073255           6.778645
# min                    6.400000                 -3.000000           0.000000
# 25%                   16.100000                  8.200000           0.000000
# 50%                   20.900000                 12.900000           0.100000
# 75%                   25.800000                 18.100000           1.600000
# max                   45.200000                 28.300000         138.400000
#
#           rain_sum  snowfall_sum  precipitation_hours  sunshine_duration  \
# count  4745.000000        4745.0          4745.000000        4745.000000
# mean      2.388788           0.0             3.870179       34137.621294
# std       6.778645           0.0             5.825600       11149.439666
# min       0.000000           0.0             0.000000           0.000000
# 25%       0.000000           0.0             0.000000       31492.620000
# 50%       0.100000           0.0             1.000000       35759.250000
# 75%       1.600000           0.0             6.000000       41871.910000
# max     138.400000           0.0            24.000000       48622.640000
#
#        daylight_duration  wind_speed_10m_max  wind_gusts_10m_max  \
# count        4745.000000         4745.000000         4745.000000
# mean        43579.511538           18.846175           40.328008
# std          5587.477501            6.543147           12.773165
# min         35634.250000            5.100000           12.600000
# 25%         38132.550000           14.000000           31.300000
# 50%         43434.160000           18.000000           39.200000
# 75%         48999.410000           22.600000           47.500000
# max         51862.750000           48.800000          102.200000
#
#        wind_direction_10m_dominant  shortwave_radiation_sum  \
# count                  4745.000000              4745.000000
# mean                    181.226133                16.745246
# std                     103.025724                 7.144935
# min                       0.000000                 0.810000
# 25%                      85.000000                11.250000
# 50%                     183.000000                15.740000
# 75%                     272.000000                22.090000
# max                     360.000000                33.660000
#
#        et0_fao_evapotranspiration  rain_in_7_days  precipitation_next_3_days
# count                 4745.000000     4745.000000                4745.000000
# mean                     3.288451        0.514858                   7.162993
# std                      1.467123        0.499832                  15.056498
# min                      0.340000        0.000000                   0.000000
# 25%                      2.150000        0.000000                   0.100000
# 50%                      3.100000        1.000000                   1.700000
# 75%                      4.280000        1.000000                   7.200000
# max                      9.640000        1.000000                 203.700000

# %%
df['snowfall_sum'].value_counts()
# Out:
# snowfall_sum
# 0.0    4745
# Name: count, dtype: int64
