# %%
import sys
sys.path.append('../data')

from fetch_openmeteo_data import fetch_weather_data

# Fetch data
df = fetch_weather_data(start_year=2010, end_year=2024, save_path="../data/raw/sydney_weather_2010_2024.csv")
# Out:
# Fetching data by year:  93%|██████████████████▋ | 14/15 [00:21<00:01,  1.51s/it]
# Failed to fetch data for year 2023, status code: 429
# Fetching data by year: 100%|████████████████████| 15/15 [00:22<00:00,  1.53s/it]
# Failed to fetch data for year 2024, status code: 429
# Saved dataset to ../data/raw/sydney_weather_2010_2024.csv
